# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 160

import pickle

from slider import Preprocessing, Settings, Visualization
from slider import ImageAnalysis, ParticleAnalysis, NetworkAnalysis, CommunityAnalysis, Analyze

# %%
photoelasticImageData, whiteLightImageData, forceData, trackingData, metadata = Preprocessing.loadSliderData(loadCachedData=True)
peakTimes = Preprocessing.identifyPeaks(forceData, returnTimes=True)
peakIndices = Preprocessing.identifyPeaks(forceData)
timeArr = forceData[0][:,1]
# Out:
# Reading tracking data from cache: Cache/Tracking/shape0_01.pickle

# %%
metrics = [CommunityAnalysis.averageCommunitySize, CommunityAnalysis.numberOfCommunities]

metricList = Analyze.analyze(photoelasticImageData, trackingData, metrics, metadata)
# Out:
# Performing community analysis:
#   0% (4 of 21997) |                | Elapsed Time: 0:00:18 ETA:  1 day, 4:17:36
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-af3d99bc0e05> in <module>
#       1 metrics = [CommunityAnalysis.averageCommunitySize, CommunityAnalysis.numberOfCommunities]
#       2
# ----> 3 metricList = Analyze.analyze(photoelasticImageData, trackingData, metrics, metadata)
#
# ~/workspaces/jupyter-workspace/FailurePrediction/slider/Analyze.py in analyze(photoelasticImageData, trackingData, metrics, metadata, loadCachedResults, saveCachedResults, progress, DATA_LOCATION, CACHE_DIR, ANALYSIS_DIR)
#     264         else:
#     265             currMetadata = None
# --> 266         newMetrics = analyze(photoelasticImageData[k], trackingData[k], metrics, metadata=currMetadata, loadCachedResults=loadCachedResults, progress=progress,
#     267                              saveCachedResults=saveCachedResults, DATA_LOCATION=DATA_LOCATION, CACHE_DIR=CACHE_DIR, ANALYSIS_DIR=ANALYSIS_DIR)
#     268         finalMetrics.append(newMetrics)
#
# ~/workspaces/jupyter-workspace/FailurePrediction/slider/Analyze.py in analyze(photoelasticImageData, trackingData, metrics, metadata, loadCachedResults, saveCachedResults, progress, DATA_LOCATION, CACHE_DIR, ANALYSIS_DIR)
#     227                 frame = checkImageType(photoelasticImageData[i])
#     228
# --> 229                 graph = nx.from_numpy_array(NetworkAnalysis.genWeightedAdjacencyMatrix(pos_x, pos_y, radii, frame))
#     230
#     231                 # The number of detections to average over
#
# ~/workspaces/jupyter-workspace/FailurePrediction/slider/NetworkAnalysis.py in genWeightedAdjacencyMatrix(pos_x, pos_y, radii, photoelasticImage, padding, contactThreshold)
#      62
#      63     for i in range(len(particleGSqrs)):
# ---> 64         mask = circularMask((pos_x[i], pos_y[i]), radii[i], np.shape(frame))
#      65
#      66         particleGSqrs[i] = np.sum(np.multiply(gSqr, mask))
#
# ~/workspaces/jupyter-workspace/FailurePrediction/slider/NetworkAnalysis.py in circularMask(center, radius, imageSize)
#      40     h, w = imageSize
#      41     Y, X = np.ogrid[:h, :w]
# ---> 42     dist_from_center = np.sqrt((X - center[0])**2 + (Y-center[1])**2)
#      43
#      44     mask = dist_from_center <= radius
#
# KeyboardInterrupt:

# %%
for i in range(len(peakTimes[0])):
    plt.axvline(peakTimes[0][i], c='r', alpha=.4)

plt.plot(timeArr, metricList[0][1])
plt.ylabel('Average Brightness')
plt.xlabel('Time [s]')
plt.savefig('images/averageBrightness.png')

# %%
for i in range(len(peakTimes[0])):
    plt.axvline(peakTimes[0][i], c='r', alpha=.4)

plt.plot(timeArr, metricList[0][0])
plt.ylabel('Variance in Brightness')
plt.xlabel('Time [s]')
plt.savefig('images/averageBrightness.png')

# %%
for i in range(len(peakTimes[0])):
    plt.axvline(peakTimes[0][i], c='r', alpha=.4)

plt.plot(timeArr, metricList[0][0])
plt.ylabel('Average Community Size')
plt.xlabel('Time [s]')
plt.savefig('images/averageCommunitySize.png')

# %%
ind = 7
width = 300
a = peakIndices[0][ind] - width
b = a + 2*width

for i in range(len(peakTimes[0])):
    plt.axvline(peakTimes[0][i], c='r', alpha=.4)

plt.plot(timeArr, metricList[0][1])
plt.ylabel('Average Community Size')
plt.xlabel('Time [s]')
plt.xlim([timeArr[a], timeArr[b]])
plt.savefig('images/com_size_local.png')
plt.show()

# %%
for i in range(len(peakTimes[0])):
    plt.axvline(peakTimes[0][i], c='r', alpha=.4)

plt.plot(timeArr, metricList[0][1])
plt.ylabel('Number of Communities')
plt.xlabel('Time [s]')
plt.savefig('images/numberOfCommunities.png')

# %%
for i in range(len(peakTimes[0])):
    plt.axvline(peakTimes[0][i], c='r', alpha=.4)

plt.plot(timeArr, metricList[0][0])
plt.ylabel('Average Coordination Number')
plt.xlabel('Time [s]')
plt.savefig('images/averageCoordinationNumber.png')
